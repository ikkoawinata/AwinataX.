# %% [markdown]
# <a href="https://colab.research.google.com/github/ikkoawinata/AwinataX./blob/ikkoawinata.github.io/Salinan_dari_Bangkit_ML_Project_Fix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Download the dataset
file_id = '1TLPrez6to0VRQCxt5L4NgK4tejMBYbTA'

output_file = 'Dataset.zip'

# Generate the download link
download_link = f'https://drive.google.com/uc?id={file_id}'

# Download the file
# !gdown $download_link -O $output_file
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1TLPrez6to0VRQCxt5L4NgK4tejMBYbTA
# From (redirected): https://drive.google.com/uc?id=1TLPrez6to0VRQCxt5L4NgK4tejMBYbTA&confirm=t&uuid=aa22db38-3b36-47f4-bac8-bf4258b120fa
# To: /content/Dataset.zip
# 100% 89.8M/89.8M [00:03<00:00, 24.6MB/s]

# %%
# !unzip /content/Dataset.zip
# Out:
# Archive:  /content/Dataset.zip
#   inflating: Dataset/validation/telur/telur-11.jpg
#   inflating: Dataset/validation/telur/telur-val-4.jpg
#   inflating: Dataset/validation/telur/telur-val-2.jpg
#   inflating: Dataset/validation/telur/telur-val-5.jpg
#   inflating: Dataset/validation/telur/telur-23.jpg
#   inflating: Dataset/validation/telur/telur-val-6.jpg
#   inflating: Dataset/validation/telur/telur-24.jpg
#   inflating: Dataset/validation/telur/2.jpg
#   inflating: Dataset/validation/telur/3.jpg
#   inflating: Dataset/train/tomat/tomat-8.jpg
#   inflating: Dataset/train/tomat/tomat-17.jpg
#   inflating: Dataset/validation/tomat/tomat-val-8.jpg
#   inflating: Dataset/train/tomat/tomat-6.jpg
#   inflating: Dataset/train/tomat/tomat-12.jpg
#   inflating: Dataset/train/tomat/tomat-13.jpg
#   inflating: Dataset/validation/telur/1.jpg
#   inflating: Dataset/train/tomat/tomat-18.jpg
#   inflating: Dataset/validation/tomat/tomat-val-9.jpg
#   inflating: Dataset/validation/tomat/tomat-val-10.jpg
#   inflating: Dataset/train/tomat/tomat-16.jpg
#   inflating: Dataset/train/tomat/tomat-14.jpg
#   inflating: Dataset/train/tomat/tomat-19.jpg
#   inflating: Dataset/train/tomat/tomat-9.JPG
#   inflating: Dataset/train/tomat/tomat-15.jpg
#   inflating: Dataset/validation/tomat/tomat-val-7.jpg
#   inflating: Dataset/train/tomat/tomat-28.jpg
#   inflating: Dataset/train/tomat/tomat-11.jpg
#   inflating: Dataset/train/tomat/tomat-20.jpg
#   inflating: Dataset/train/tomat/tomat-10.JPG
#   inflating: Dataset/train/tomat/tomat-30.jpg
#   inflating: Dataset/validation/tomat/tomat-val-5.jpg
#   inflating: Dataset/validation/tomat/tomat-val-4.jpg
#   inflating: Dataset/validation/tomat/tomat-val-2.jpg
#   inflating: Dataset/train/tomat/tomat-27.jpg
#   inflating: Dataset/train/tomat/tomat-4.jpg
#   inflating: Dataset/validation/tomat/tomat-val-1.jpg
#   inflating: Dataset/train/tomat/tomat-25.jpg
#   inflating: Dataset/validation/tomat/tomat-val-6.jpg
#   inflating: Dataset/train/tomat/tomat-29.jpg
#   inflating: Dataset/validation/tomat/tomat-val-3.jpg
#   inflating: Dataset/train/jagung/jagung-16.jpg
#   inflating: Dataset/train/jagung/jagung-8.jpg
#   inflating: Dataset/validation/kol/0037_jpg.rf.d8d88523a8af35ba361e8f69ce33e9bc.jpg
#   inflating: Dataset/train/jagung/jagung-1.jpg
#   inflating: Dataset/train/jagung/jagung-7.jpg
#   inflating: Dataset/validation/kentang/kentang-val-1.jpg
#   inflating: Dataset/train/jagung/jagung-5.jpg
#   inflating: Dataset/validation/kentang/kentang-val-8.jpg
#   inflating: Dataset/validation/kol/0029_jpg.rf.9bd6459adbff62a4e585438141e93164.jpg
#   inflating: Dataset/validation/nasi/nasi_29.jpg
#   inflating: Dataset/validation/timun/timun-val-3.jpg
#   inflating: Dataset/validation/nasi/nasi_23.jpg
#   inflating: Dataset/validation/nasi/47_jpg.rf.a0f660000352efa213ebd9dc2af0ed29.jpg
#   inflating: Dataset/train/jagung/jagung-15.jpg
#   inflating: Dataset/validation/kentang/kentang-val-10.jpg
#   inflating: Dataset/validation/nasi/nasi_28.jpg
#   inflating: Dataset/validation/mie/mie_31.jpg
#   inflating: Dataset/validation/nasi/nasi_27.jpg
#   inflating: Dataset/validation/kentang/kentang-val-2.jpg
#   inflating: Dataset/train/jagung/jagung-6.jpg
#   inflating: Dataset/train/sapi/sapi-17.jpg
#   inflating: Dataset/train/jagung/jagung-4.jpg
#   inflating: Dataset/validation/mie/mie_32.jpg
#   inflating: Dataset/validation/taoge/taoge_29.jpg
#   inflating: Dataset/validation/nasi/30_jpg.rf.8ee2fd9705d8078fd823f8014ab6d613.jpg
#   inflating: Dataset/validation/taoge/taoge_27.jpg
#   inflating: Dataset/validation/mie/mie_29.jpg
#   inflating: Dataset/train/jagung/jagung-3.jpg
#   inflating: Dataset/validation/taoge/taoge_39.jpg
#   inflating: Dataset/validation/mie/page_5_product_10_image_0_jpg.rf.2721199a0f95c6e03e742092282baf99.jpg
#   inflating: Dataset/train/jagung/jagung-22.jpg
#   inflating: Dataset/validation/mie/mie_30.jpg
#   inflating: Dataset/validation/nasi/53_jpg.rf.f80779af1127e6edbcf5e72d966635b0.jpg
#   inflating: Dataset/train/jagung/jagung-9.jpg
#   inflating: Dataset/validation/taoge/taoge_37.jpg
#   inflating: Dataset/validation/mie/page_5_product_14_image_1_jpg.rf.8a806a07ff26e29bb9bb188f50a9b17f.jpg
#   inflating: Dataset/train/terong/terong-27.jpg
#   inflating: Dataset/validation/taoge/taoge_31.jpg
#   inflating: Dataset/validation/nasi/nasi_30.jpg
#   inflating: Dataset/validation/mie/page_3_product_7_image_1_jpg.rf.ccbaa47e467ac199f6b41b138651dd01.jpg
#   inflating: Dataset/validation/taoge/taoge_25.jpg
#   inflating: Dataset/validation/taoge/taoge_24.jpg
#   inflating: Dataset/validation/mie/page_1_product_12_image_2_jpg.rf.9356b9f2d224e37f7912b0c0f08ba79f.jpg
#   inflating: Dataset/validation/mie/mie_23.jpg
jpg
#   inflating: Dataset/train/bawang bombay/bawang bombay -2.jpg
#   inflating: Dataset/validation/terong/terong-val-10.jpg
#   inflating: Dataset/train/bawang bombay/bawang bombay -7.jpg
#   inflating: Dataset/train/bawang bombay/bawang bombay - 27.jpg
#   inflating: Dataset/validation/brokoli/7WYOPSRC9XF0.jpg
#   inflating: Dataset/validation/ayam/ayam-val-7.jpg
#   inflating: Dataset/train/bawang bombay/bawang bombay -9.jpg
#   inflating: Dataset/train/terong/terong-14.jpg
#   inflating: Dataset/train/kentang/kentang-10.jpg
#   inflating: Dataset/train/bawang bombay/bawang bombay -16.jpg
#   inflating: Dataset/validation/bawang bombay/istockphoto-1154062045-612x612_jpg.rf.4fe63ee3ca8d923fb97a20bb7ff93985.jpg
#   inflating: Dataset/train/bawang bombay/bawang bombay -12.jpg
#   inflating: Dataset/train/bawang bombay/bawang bombay -17.jpg
#   inflating: Dataset/train/bawang bombay/bawang bombay -3.jpg
#   inflating: Dataset/train/bawang bombay/bawang bombay -6.jpg
#   inflating: Dataset/train/bawang bombay/bawang bombay -11.jpg
#   inflating: Dataset/train/bawang bombay/bawang bombay - 24.jpg
#   inflating: Dataset/train/bawang bombay/bawang bombay -4.jpg
#   inflating: Dataset/validation/brokoli/0F99IPIAIXE3.jpg
#   inflating: Dataset/validation/kacang panjang/kacang panjang_25.jpg
#   inflating: Dataset/train/bawang bombay/bawang bombay - 30.jpg
#   inflating: Dataset/train/bawang bombay/bawang bombay -1.jpg
#   inflating: Dataset/train/terong/terong-11.jpg
#   inflating: Dataset/validation/nasi/258_jpg.rf.ebc5f381b9f2cc70344faacf54f09b8d.jpg
#   inflating: Dataset/train/bawang bombay/bawang bombay -18.jpg
#   inflating: Dataset/validation/kacang panjang/kacang panjang_39.jpg
#   inflating: Dataset/validation/kacang panjang/kacang panjang_30.jpg
#   inflating: Dataset/validation/jagung/jagung-val-6.jpg
#   inflating: Dataset/train/bawang bombay/bawang bombay -15.jpg
#   inflating: Dataset/validation/jagung/jagung-val-9.JPG
#   inflating: Dataset/train/bawang bombay/bawang bombay -13.jpg
#   inflating: Dataset/train/bawang bombay/bawang bombay -10.jpg
#   inflating: Dataset/train/bawang bombay/bawang bombay -19.jpg
#   inflating: Dataset/validation/jagung/jagung-val-10.jpg
#   inflating: Dataset/validation/kacang panjang/kacang panjang_40.jpg
#   inflating: Dataset/validation/jagung/jagung-val-4.jpg
#   inflating: Dataset/validation/bawang bombay/istockphoto-919165148-612x612_jpg.rf.0582f24e81d2acaf26a64e2f30394bbc.jpg
#   inflating: Dataset/train/bawang bombay/bawang bombay -14.jpg
#   inflating: Dataset/validation/kacang panjang/kacang panjang_23.jpg
#   inflating: Dataset/validation/kacang panjang/kacang panjang_33.jpg
#   inflating: Dataset/train/bawang bombay/bawang bombay - 23.jpg
#   inflating: Dataset/validation/ayam/ayam-val-3.jpg
#   inflating: Dataset/validation/kacang panjang/kacang panjang_38.jpg
#   inflating: Dataset/validation/jagung/jagung-val-1.jpg
#   inflating: Dataset/validation/jagung/jagung-val-3.jpg
#   inflating: Dataset/validation/jagung/jagung-val-7.jpg
#   inflating: Dataset/train/bawang bombay/bawang bombay -8.jpg
#   inflating: Dataset/validation/kacang panjang/kacang panjang_21.jpg
#   inflating: Dataset/validation/kacang panjang/kacang panjang_35.jpg
#   inflating: Dataset/validation/jagung/jagung-val-2.jpg
#   inflating: Dataset/validation/kacang panjang/kacang panjang_27.jpg
#   inflating: Dataset/validation/jagung/jagung-val-5.jpg
#   inflating: Dataset/train/bawang bombay/bawang bombay -20.jpg
#   inflating: Dataset/validation/jagung/jagung-val-8.jpg

# %%
import os
import numpy as np
import tensorflow as tf
import tensorflow_hub as hub
import matplotlib.pyplot as plt
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_dir = "/content/Dataset/train/"
validation_dir = "/content/Dataset/validation/"

sorted_labels = [
    'ayam', 'bawang bombay', 'bawang merah', 'bawang putih', 'bayam', 'brokoli',
    'buncis', 'cabai', 'daun singkong', 'ikan', 'jagung',
    'jamur',  'kacang panjang', 'kambing', 'kangkung', 'kentang', 'kol', 'mie', 'nasi',
    'sapi', 'sawi', 'serai',  'tahu', 'taoge', 'telur', 'tempe', 'terong', 'timun',
    'tomat',  'udang', 'wortel'
]

# train directories
train_directories = {label: os.path.join(train_dir, label) for label in sorted_labels}

# validation directories
validation_directories = {label: os.path.join(validation_dir, label) for label in sorted_labels}

for label in sorted_labels:
    print('Total training', label, 'images:', len(os.listdir(train_directories[label])))

for label in sorted_labels:
    print('Total validation', label, 'images:', len(os.listdir(validation_directories[label])))

jamur_file = os.listdir(train_directories['jamur'])
print(jamur_file[:5])
# Out:
# Total training ayam images: 30
# Total training bawang bombay images: 30
# Total training bawang merah images: 30
# Total training bawang putih images: 30
# Total training bayam images: 30
# Total training brokoli images: 30
# Total training buncis images: 30
# Total training cabai images: 30
# Total training daun singkong images: 30
# Total training ikan images: 30
# Total training jagung images: 30
# Total training jamur images: 30
# Total training kacang panjang images: 30
# Total training kambing images: 30
# Total training kangkung images: 30
# Total training kentang images: 30
# Total training kol images: 30
# Total training mie images: 30
# Total training nasi images: 30
# Total training sapi images: 30
# Total training sawi images: 30
# Total training serai images: 30
# Total training tahu images: 30
# Total training taoge images: 30
# Total training telur images: 30
# Total training tempe images: 30
# Total training terong images: 30
# Total training timun images: 30
# Total training tomat images: 30
# Total training udang images: 30
# Total training wortel images: 30
# Total validation ayam images: 10
# Total validation bawang bombay images: 10
# Total validation bawang merah images: 10
# Total validation bawang putih images: 10
# Total validation bayam images: 10
# Total validation brokoli images: 10
# Total validation buncis images: 10
# Total validation cabai images: 10
# Total validation daun singkong images: 10
# Total validation ikan images: 10
# Total validation jagung images: 10
# Total validation jamur images: 10
# Total validation kacang panjang images: 10
# Total validation kambing images: 10
# Total validation kangkung images: 10
# Total validation kentang images: 10
# Total validation kol images: 10
# Total validation mie images: 10
# Total validation nasi images: 10
# Total validation sapi images: 10
# Total validation sawi images: 10
# Total validation serai images: 10
# Total validation tahu images: 10
# Total validation taoge images: 10
# Total validation telur images: 10
# Total validation tempe images: 10
# Total validation terong images: 10
# Total validation timun images: 10
# Total validation tomat images: 10
# Total validation udang images: 10
# Total validation wortel images: 10
# ['page_2_product_5_image_0_jpg.rf.57a122796bfffea960fdd26e76f2efc5.jpg', 'jamur7_istockphoto-1297252439-1024x1024.jpg', 'jamur_12.jpg', 'page_1_product_18_image_0_jpg.rf.31e295e259fe438ae7e97f439e511726.jpg', 'jamur_36.jpg']

# %%
# Feature extractor layer
feature_extractor_url = 'https://tfhub.dev/google/efficientnet/b7/feature-vector/1'
feature_extractor_layer = hub.KerasLayer(feature_extractor_url, input_shape=[512,512,3])
feature_extractor_layer.trainable = False

# %%
# Model
model = tf.keras.Sequential([
    feature_extractor_layer,
    tf.keras.layers.Dense(1024, activation="relu"),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Dense(256, activation="relu"),
    tf.keras.layers.Dense(31, activation="softmax")
])

model.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-d4a30e6ec3df> in <cell line: 2>()
#       1 # Model
# ----> 2 model = tf.keras.Sequential([
#       3     feature_extractor_layer,
#       4     tf.keras.layers.Dense(1024, activation="relu"),
#       5     tf.keras.layers.Dropout(0.25),
#
# /usr/local/lib/python3.10/dist-packages/keras/src/models/sequential.py in __init__(self, layers, trainable, name)
#      71         if layers:
#      72             for layer in layers:
# ---> 73                 self.add(layer, rebuild=False)
#      74             self._maybe_rebuild()
#      75
#
# /usr/local/lib/python3.10/dist-packages/keras/src/models/sequential.py in add(self, layer, rebuild)
#      93                 layer = origin_layer
#      94         if not isinstance(layer, Layer):
# ---> 95             raise ValueError(
#      96                 "Only instances of `keras.Layer` can be "
#      97                 f"added to a Sequential model. Received: {layer} "
#
# ValueError: Only instances of `keras.Layer` can be added to a Sequential model. Received: <tensorflow_hub.keras_layer.KerasLayer object at 0x78b33e14a110> (of type <class 'tensorflow_hub.keras_layer.KerasLayer'>)

# %%
model.compile(optimizer= 'Adam',
              loss= 'categorical_crossentropy',
              metrics= ['accuracy'])

# %%
# Add data-augmentation parameters to ImageDataGenerator
train_datagen = ImageDataGenerator(rescale= 1./255,
                                   rotation_range= 50,
                                   width_shift_range= 0.3,
                                   height_shift_range= 0.3,
                                   shear_range= 0.3,
                                   zoom_range= 0.3,
                                   horizontal_flip= True,
                                   fill_mode= 'nearest')

# Flow training images in batches of 31 using train_datagen generator
train_generator = train_datagen.flow_from_directory(train_dir,
                                                    batch_size= 31,
                                                    class_mode= 'categorical',
                                                    target_size= (512, 512))

validation_datagen = ImageDataGenerator(rescale = 1./255)

# Flow validation images in batches of 31 using validation_datagen generator
validation_generator = validation_datagen.flow_from_directory(validation_dir,
                                                    batch_size= 31,
                                                    class_mode= 'categorical',
                                                    target_size= (512, 512))

# %%
class Callback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('accuracy')>0.95):
      print("\nReached 95% accuracy so cancelling training!")
      self.model.stop_training = True

callbacks = Callback()

# Train the model
history = model.fit(train_generator,
                    epochs= 20,
                    validation_data= validation_generator,
                    verbose= 1,
                    callbacks= callbacks)

# %%
# Plot the results
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

# Plot the accuracy
plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)
plt.figure()

# Plot the loss
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend(loc=0)
plt.figure()

plt.show()

# %%
# Predictions from validation folder
from tensorflow.keras.preprocessing import image

for label in sorted_labels:
  folder = validation_directories[label]

  for path_file in os.listdir(folder):
    # Get value from image
    path_file = os.path.join(folder, path_file)
    img = image.load_img(path_file, target_size=(512, 512))
    x = img_to_array(img)
    x = x/255
    x = np.expand_dims(x, axis=0)

    # Predict the image label
    images = np.vstack([x])
    classes = model.predict(images, batch_size=31)

    # Take the class index with the highest probability
    predicted_class_index = classes.argmax()

    # Convert class indices to label
    predicted_label = sorted_labels[predicted_class_index]

    print("Label:", label, "Predicted Label:", predicted_label)

# %%
# Test the model using the uploaded image
from google.colab import files
from PIL import Image as PILImage

uploaded = files.upload()

for fn in uploaded.keys():
  # Get value from image
  path = '/content/' + fn
  img = PILImage.open(path)
  img = image.load_img(path, target_size=(512, 512))

  # Display image
  plt.imshow(img)
  plt.axis('off')
  plt.show()

  x = img_to_array(img)
  x = x/255
  x = np.expand_dims(x, axis=0)

  # Predict the image label
  images = np.vstack([x])
  classes = model.predict(images, batch_size=31)

  # Sort the classes from highest probability
  sorted_classes = np.argsort(classes)[0, ::-1]

  # Print the detected ingredients with a threshold of 0.05
  print("Ingredients detected:")
  for index in sorted_classes:
    label = sorted_labels[index]
    prob = classes[0, index]
    if prob > 0.05:
      print(f"{label}: {prob:.4f}")

  # Delete images after use
  os.remove(path)

# %%
# Save the model
model.save("Model.h5")

# %%
# Move the saved model to Google Drive
from google.colab import drive
drive.mount('/content/gdrive')

import shutil

local_file_path = '/content/Model.h5'
drive_path = '/content/gdrive/My Drive/'

shutil.copy(local_file_path, drive_path)
